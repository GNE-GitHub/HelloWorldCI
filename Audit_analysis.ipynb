# %% [markdown]
# <a href="https://colab.research.google.com/github/GNE-GitHub/HelloWorldCI/blob/main/Audit_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# قراءة البيانات من ملف CSV
audit_data = pd.read_csv('audit_data_master_csv.csv')

# عرض أول 5 صفوف من البيانات
print(audit_data.head())

# عرض معلومات عامة حول البيانات (الأعمدة، الأنواع، القيم المفقودة)
print(audit_data.info())

# وصف إحصائي للبيانات
print(audit_data.describe())
# Out:
#                    event_time  sequence_number action_id  succeeded  \
# 0  2024-08-17 06:31:57.367690                1      AUSC       True
# 1  2024-08-17 06:37:18.042834                1      SL         True
# 2  2024-08-17 06:37:18.042834                1      SL         True
# 3  2024-08-17 06:37:18.326834                1      SL         True
# 4  2024-08-17 06:37:18.326834                1      SL         True
#
#    permission_bitmask  is_column_permission  session_id  server_principal_id  \
# 0                 NaN                 False           9                    1
# 1                 NaN                  True          59                  265
# 2                 NaN                  True          59                  265
# 3                 NaN                  True          59                  265
# 4                 NaN                  True          59                  265
#
#    database_principal_id  target_server_principal_id  ...  sequence_group_id  \
# 0                      0                           0  ...                NaN
# 1                      0                           0  ...  kQd±çJÆ\n&
# k»EC(qlI×i»
# 3                      0                           0  ...  GÚ#\tlæ]MºooêÔ«U
# 4                      0                           0  ...   7r\_O.½mL¥w
#
#    transaction_id      client_ip application_name duration_milliseconds  \
# 0               0        Unknown              NaN                     0
# 1            4945  local machine    SQLServerCEIP                     0
# 2            4945  local machine    SQLServerCEIP                     0
# 3            4967  local machine    SQLServerCEIP                     0
# 4            4967  local machine    SQLServerCEIP                     0
#
#   response_rows affected_rows                         connection_id  \
# 0             0             0  00000000-0000-0000-0000-000000000000
# 1             0             0  0C1D1786-A0FC-4D07-93B0-087728151D8B
# 2             0             0  0C1D1786-A0FC-4D07-93B0-087728151D8B
# 3             0             0  0C1D1786-A0FC-4D07-93B0-087728151D8B
# 4             0             0  0C1D1786-A0FC-4D07-93B0-087728151D8B
#
#    data_sensitivity_information        host_name
# 0                           NaN              NaN
# 1                           NaN  DESKTOP-55IP1AV
# 2                           NaN  DESKTOP-55IP1AV
# 3                           NaN  DESKTOP-55IP1AV
# 4                           NaN  DESKTOP-55IP1AV
#
# [5 rows x 41 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7920 entries, 0 to 7919
# Data columns (total 41 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   event_time                      7920 non-null   object
#  1   sequence_number                 7920 non-null   int64
#  2   action_id                       7920 non-null   object
#  3   succeeded                       7920 non-null   bool
#  4   permission_bitmask              0 non-null      float64
#  5   is_column_permission            7920 non-null   bool
#  6   session_id                      7920 non-null   int64
#  7   server_principal_id             7920 non-null   int64
#  8   database_principal_id           7920 non-null   int64
#  9   target_server_principal_id      7920 non-null   int64
#  10  target_database_principal_id    7920 non-null   int64
#  11  object_id                       7920 non-null   int64
#  12  class_type                      7920 non-null   object
#  13  session_server_principal_name   7919 non-null   object
#  14  server_principal_name           7920 non-null   object
#  15  server_principal_sid            7920 non-null   object
#  16  database_principal_name         7919 non-null   object
#  17  target_server_principal_name    0 non-null      float64
#  18  target_server_principal_sid     0 non-null      float64
#  19  target_database_principal_name  0 non-null      float64
#  20  server_instance_name            7920 non-null   object
#  21  database_name                   7919 non-null   object
#  22  schema_name                     7919 non-null   object
#  23  object_name                     7919 non-null   object
#  24  statement                       7822 non-null   object
#  25  additional_information          342 non-null    object
#  26  file_name                       7920 non-null   object
#  27  audit_file_offset               7920 non-null   int64
#  28  user_defined_event_id           7920 non-null   int64
#  29  user_defined_information        0 non-null      float64
#  30  audit_schema_version            7920 non-null   int64
#  31  sequence_group_id               7888 non-null   object
#  32  transaction_id                  7920 non-null   int64
#  33  client_ip                       7920 non-null   object
#  34  application_name                7919 non-null   object
#  35  duration_milliseconds           7920 non-null   int64
#  36  response_rows                   7920 non-null   int64
#  37  affected_rows                   7920 non-null   int64
#  38  connection_id                   7920 non-null   object
#  39  data_sensitivity_information    0 non-null      float64
#  40  host_name                       7919 non-null   object
# dtypes: bool(2), float64(6), int64(14), object(19)
# memory usage: 2.4+ MB
# None
#        sequence_number  permission_bitmask   session_id  server_principal_id  \
# count      7920.000000                 0.0  7920.000000          7920.000000
# mean          1.059596                 NaN    59.281944           262.465152
# std           0.247189                 NaN     6.144916             4.169632
# min           1.000000                 NaN     9.000000             1.000000
# 25%           1.000000                 NaN    57.000000           259.000000
# 50%           1.000000                 NaN    59.000000           265.000000
# 75%           1.000000                 NaN    59.000000           265.000000
# max           3.000000                 NaN    89.000000           265.000000
#
#        database_principal_id  target_server_principal_id  \
# count            7920.000000                      7920.0
# mean                0.416919                         0.0
# std                 0.493080                         0.0
# min                 0.000000                         0.0
# 25%                 0.000000                         0.0
# 50%                 0.000000                         0.0
# 75%                 1.000000                         0.0
# max                 1.000000                         0.0
#
#        target_database_principal_id     object_id  \
# count                        7920.0  7.920000e+03
# mean                            0.0 -2.995932e+08
# std                             0.0  2.802787e+08
# min                             0.0 -1.057317e+09
# 25%                             0.0 -5.068645e+08
# 50%                             0.0 -1.544195e+08
# 75%                             0.0 -1.479186e+08
# max                             0.0  0.000000e+00
#
#        target_server_principal_name  target_server_principal_sid  \
# count                           0.0                          0.0
# mean                            NaN                          NaN
# std                             NaN                          NaN
# min                             NaN                          NaN
# 25%                             NaN                          NaN
# 50%                             NaN                          NaN
# 75%                             NaN                          NaN
# max                             NaN                          NaN
#
#        target_database_principal_name  audit_file_offset  \
# count                             0.0       7.920000e+03
# mean                              NaN       6.286113e+06
# std                               NaN       4.414705e+06
# min                               NaN       5.632000e+03
# 25%                               NaN       2.641408e+06
# 50%                               NaN       5.336576e+06
# 75%                               NaN       8.519680e+06
# max                               NaN       1.628416e+07
#
#        user_defined_event_id  user_defined_information  audit_schema_version  \
# count                 7920.0                       0.0                7920.0
# mean                     0.0                       NaN                   1.0
# std                      0.0                       NaN                   0.0
# min                      0.0                       NaN                   1.0
# 25%                      0.0                       NaN                   1.0
# 50%                      0.0                       NaN                   1.0
# 75%                      0.0                       NaN                   1.0
# max                      0.0                       NaN                   1.0
#
#        transaction_id  duration_milliseconds  response_rows  affected_rows  \
# count     7920.000000                 7920.0         7920.0         7920.0
# mean    396706.894949                    0.0            0.0            0.0
# std     321793.589986                    0.0            0.0            0.0
# min          0.000000                    0.0            0.0            0.0
# 25%     119861.000000                    0.0            0.0            0.0
# 50%     178235.000000                    0.0            0.0            0.0
# 75%     767944.000000                    0.0            0.0            0.0
# max     820103.000000                    0.0            0.0            0.0
#
#        data_sensitivity_information
# count                           0.0
# mean                            NaN
# std                             NaN
# min                             NaN
# 25%                             NaN
# 50%                             NaN
# 75%                             NaN
# max                             NaN

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %% [markdown]
# > Add blockquote
#
# *   List item\\
#
# ---
#
# \
# dxasasd:w
#
# ```
# [# This is formatted as code](https://[link text](`https://`))
# ```

# %%
import pandas as pd
import matplotlib.pyplot as plt

# قراءة البيانات من ملف CSV
audit_data = pd.read_csv('audit_data_master_csv.csv')

# تحويل عمود event_time إلى صيغة datetime
audit_data['event_time'] = pd.to_datetime(audit_data['event_time'])

# تعيين event_time كفهرس للبيانات
audit_data.set_index('event_time', inplace=True)

# رسم توزيع الأحداث على مدار الوقت
plt.figure(figsize=(14, 7))
audit_data['sequence_number'].resample('H').count().plot()
plt.title('Distribution of Events Over Time')
plt.xlabel('Time')
plt.ylabel('Number of Events')
plt.show()

# %%
import pandas as pd

# قراءة البيانات
df = pd.read_csv('audit_data_master_csv.csv')

# حذف أي صفوف تحتوي على قيم مفقودة في الأعمدة المهمة
df_cleaned = df.dropna(subset=['session_server_principal_name', 'action_id'])

# تجميع البيانات حسب المستخدم والنشاطات مع عدّ عدد مرات النجاح والفشل
user_activity = df_cleaned.groupby(['session_server_principal_name', 'action_id'])['succeeded'].value_counts().unstack().fillna(0)

# عرض النتائج
print(user_activity)
# Out:
# succeeded                                True
# session_server_principal_name action_id
# DESKTOP-55IP1AV\pc            EX          236
#                               SL         3066
# NT Service\SQLTELEMETRY       EX            1
#                               SL         4616

# %%
import pandas as pd

# قراءة البيانات
df = pd.read_csv('audit_data_master_csv.csv')

# تحليل نسبة النجاح والفشل
success_rate = df['succeeded'].value_counts(normalize=True) * 100
print("نسبة النجاح والفشل:")
print(success_rate)

# تحليل الارتباط بين succeeded و action_id
action_success = df.groupby(['action_id', 'succeeded']).size().unstack(fill_value=0)
print("\nتحليل الارتباط بين succeeded و action_id:")
print(action_success)

# إذا كان عمود permission_bitmask يحتوي على قيم
if not df['permission_bitmask'].isnull().all():
    permission_success = df.groupby(['permission_bitmask', 'succeeded']).size().unstack(fill_value=0)
    print("\nتحليل الارتباط بين succeeded و permission_bitmask:")
    print(permission_success)
else:
    print("\nعمود permission_bitmask يحتوي على قيم فارغة فقط، لا يمكن تحليل الارتباط.")

# تحديد العمليات أو النشاطات التي تتطلب مزيدًا من الانتباه
failed_actions = action_success[action_success[False] > 0]
print("\nالعمليات التي تحتاج إلى مزيد من الانتباه:")
print(failed_actions)
# Out:
# نسبة النجاح والفشل:
# succeeded
# True    100.0
# Name: proportion, dtype: float64
#
# تحليل الارتباط بين succeeded و action_id:
# succeeded  True
# action_id
# AUSC          1
# EX          237
# SL         7682
#
# عمود permission_bitmask يحتوي على قيم فارغة فقط، لا يمكن تحليل الارتباط.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.UInt8HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.UInt8HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-7fd47192e989> in <cell line: 25>()
#      23
#      24 # تحديد العمليات أو النشاطات التي تتطلب مزيدًا من الانتباه
# ---> 25 failed_actions = action_success[action_success[False] > 0]
#      26 print("\nالعمليات التي تحتاج إلى مزيد من الانتباه:")
#      27 print(failed_actions)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3891             if self.columns.nlevels > 1:
#    3892                 return self._getitem_multilevel(key)
# -> 3893             indexer = self.columns.get_loc(key)
#    3894             if is_integer(indexer):
#    3895                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3796             ):
#    3797                 raise InvalidIndexError(key)
# -> 3798             raise KeyError(key) from err
#    3799         except TypeError:
#    3800             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: False

# %%
import pandas as pd
import matplotlib.pyplot as plt

# افترض أن البيانات تم تحميلها في DataFrame يسمى df
df = pd.read_csv('audit_data_master_csv.csv')

# عرض وصف عام لعمدة duration_milliseconds
print(df['duration_milliseconds'].describe())

# رسم بياني لتوزيع duration_milliseconds
plt.figure(figsize=(10, 6))
plt.hist(df['duration_milliseconds'], bins=50, color='skyblue')
plt.title('Distribution of Duration (milliseconds)')
plt.xlabel('Duration (milliseconds)')
plt.ylabel('Frequency')
plt.show()

# تحديد العمليات ذات الزمن المستغرق الطويل
high_duration_operations = df[df['duration_milliseconds'] > df['duration_milliseconds'].quantile(0.95)]
print("High duration operations:")
print(high_duration_operations[['session_id', 'duration_milliseconds', 'action_id']])

# تحليل العلاقة بين session_id و duration_milliseconds
session_duration_mean = df.groupby('session_id')['duration_milliseconds'].mean()
session_duration_mean_sorted = session_duration_mean.sort_values(ascending=False)

print("Top sessions by average duration:")
print(session_duration_mean_sorted.head(10))

# رسم بياني لجلسات محددة وزمنها المستغرق
plt.figure(figsize=(10, 6))
session_duration_mean_sorted.head(10).plot(kind='bar', color='orange')
plt.title('Top 10 Sessions by Average Duration (milliseconds)')
plt.xlabel('Session ID')
plt.ylabel('Average Duration (milliseconds)')
plt.show()
# Out:
# count    7920.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0
# Name: duration_milliseconds, dtype: float64
# High duration operations:
# Empty DataFrame
# Columns: [session_id, duration_milliseconds, action_id]
# Index: []
# Top sessions by average duration:
# session_id
# 9     0.0
# 51    0.0
# 88    0.0
# 87    0.0
# 85    0.0
# 84    0.0
# 83    0.0
# 73    0.0
# 72    0.0
# 71    0.0
# Name: duration_milliseconds, dtype: float64
